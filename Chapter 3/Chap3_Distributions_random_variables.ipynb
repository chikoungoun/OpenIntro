# %% [markdown]
# # Distribution of Random Variables

# %% [markdown]
# ## 3.1 Normal Distribution

# %% [markdown]
# Many variables are nearly normal, but none are exactly normal.

# %%
from IPython.display import Image
Image(filename="../img/gauss.png")

# %% [markdown]
# The normal distribution model can be adjusted using 2 **parameters** : **mean** and **standard deviation**.
# * changing **mean** shifts the bell to the left or right
# * changing **standard deviation** stretches or constricts the curve

# %% [markdown]
# The Normal distribution can be written : $N(\mu,\sigma)$.(ex mean = 5 and standard deviation = 3 $N(\mu=5,\sigma=3)$)

# %% [markdown]
# The normal distribution with mean 0 and standard deviation 1 is called ** the standard normal distribution**

# %% [markdown]
# ### 3.1.1. Standardizing with Z-scores

# %% [markdown]
# * **Z-score**<br\>
# is defined as the number of standard deviations it falls above or below the mean. If the observation is one standard deviation above the mean, its Z-score is 1 positive. It's written :<br\><br\>
# <h2>$ z = \frac{x - \mu}{\sigma}$</h2>

# %% [markdown]
# If a Z-score $Z_1$ absolute value is higher than of a Z-score $Z_2$, then $Z_1$ is considered as ** more unusual **

# %% [markdown]
# **Example : ** suppose a normal distribution $N(21,5)$. Let's calculate Tom's Z-score, he who got 24 on his ACT

# %% [markdown]
# <h2>$ z = \frac{x - \mu}{\sigma} = \frac{24 - 21}{5} = 0.6$</h2>

# %% [markdown]
# * Observations above the mean always have a positive Z-score

# %% [markdown]
# ### 3.1.2. Normal probability table

# %% [markdown]
# **Percentile** is the percentage of data below a certain observations. On a normal distribution, we read it from left to right.

# %%
from IPython.display import Image
Image(filename="../img/percentile.png")

# %% [markdown]
# or the 84th percentile

# %% [markdown]
# The percentile is found through the **Z-score**. By matching the corresponding number on the **Normal Probability Table**.

# %% [markdown]
# **Example : ** Suppose the Z-Score Z = 0.43. We can find the corresponding percentile thru the normal probability table

# %%
from IPython.display import Image
Image(filename="../img/Normal_probability_table.png")

# %% [markdown]
# we find that it's percentile is 0.6664, or that it's on the 66.64th percentile or that 66.64% of the datas are below the observation.

# %% [markdown]
# * Knowing that the area of the distribution sums up to 1. It is possible to determine the area above the Z-score by substracting 1.
#
# ex: $1 - 0.6664 = 0.3336$. =>
# 33.36% of the data are above the observation.

# %% [markdown]
# * By reversing the porcedure, it is lso possible to find a Z-score from the percentile in the norma table probability. The number to choose should be the closest to the target.

# %% [markdown]
# ### 3.1.3. Rule 68 - 95 - 99.7

# %%
from IPython.display import Image
Image(filename="../img/68-95-99.png")

# %% [markdown]
# Probability for falling within 1,2 and 3 standard deviations of the mean in a normal distribution
